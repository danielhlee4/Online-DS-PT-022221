# %% [markdown]
# # All Pandas All The Time
#
# Pandas is a library we're going to be using pretty much every day in this course, so we're going to do a ton of practice so you can be on your way to becoming a _PANDAS MASTER_.
#
# ![Kung fu panda excited](https://data.whicdn.com/images/201331793/original.gif)

# %% [markdown]
# Let's continue with the data from the Austin Animal Shelter.
#
# Data source: [intakes data](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm) and [outcomes data](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Outcomes/9t4d-g238).
#
# Once again starting off with intake data, which is data describing the animals as they enter the shelter.

# %%
# Imports! Can't use pandas unless we bring it into our notebook
import pandas as pd

# %%
# !ls data/
# Out:
# Austin_Animal_Center_Intakes_030921.csv
# Austin_Animal_Center_Outcomes_030921.csv
# flights.db
# titanic.csv

# %%
# Grab the data, naming the dataframe 'intakes' this time
# Don't forget to read in DateTime as a datetime column
intakes = pd.read_csv('data/Austin_Animal_Center_Intakes_030921.csv', parse_dates=["DateTime"])

# %%
# Check out the first few rows
intakes.head()
# Out:
#   Animal ID     Name            DateTime               MonthYear  \
# 0   A786884   *Brock 2019-01-03 16:19:00  01/03/2019 04:19:00 PM
# 1   A706918    Belle 2015-07-05 12:59:00  07/05/2015 12:59:00 PM
# 2   A724273  Runster 2016-04-14 18:43:00  04/14/2016 06:43:00 PM
# 3   A665644      NaN 2013-10-21 07:59:00  10/21/2013 07:59:00 AM
# 4   A682524      Rio 2014-06-29 10:38:00  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
# Check information on the dataframe
intakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124222 entries, 0 to 124221
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         124222 non-null  object
#  1   Name              85158 non-null   object
#  2   DateTime          124222 non-null  datetime64[ns]
#  3   MonthYear         124222 non-null  object
#  4   Found Location    124222 non-null  object
#  5   Intake Type       124222 non-null  object
#  6   Intake Condition  124222 non-null  object
#  7   Animal Type       124222 non-null  object
#  8   Sex upon Intake   124221 non-null  object
#  9   Age upon Intake   124222 non-null  object
#  10  Breed             124222 non-null  object
#  11  Color             124222 non-null  object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 11.4+ MB

# %% [markdown]
# Let's do some of the transformations we did last time: dropping the MonthYear column, and changing column names to be lowercase without spaces.

# %%
# Drop MonthYear
intakes = intakes.drop(columns='MonthYear')

# %%
# Rename columns
intakes = intakes.rename(columns=lambda x: x.replace(" ","_").lower())

# %%
# Sanity check
intakes.head()
# Out:
#   animal_id     name            datetime                       found_location  \
# 0   A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1   A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2   A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 3   A665644      NaN 2013-10-21 07:59:00                          Austin (TX)
# 4   A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
#
#   intake_type intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0       Stray           Normal         Dog   Neutered Male         2 years
# 1       Stray           Normal         Dog   Spayed Female         8 years
# 2       Stray           Normal         Dog     Intact Male       11 months
# 3       Stray             Sick         Cat   Intact Female         4 weeks
# 4       Stray           Normal         Dog   Neutered Male         4 years
#
#                                    breed        color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %% [markdown]
# ## Dealing with Dirty Data
#
# It is a fact of the data science life - you will always be surrounded by 'dirty' data. What does it mean for data to be 'dirty'? What are some of the various ways that data can be 'dirty'?
#
# -

# %%
# Check for null values recognized by pandas as blank
intakes.isna().sum()
# Out:
# animal_id               0
# name                39064
# datetime                0
# found_location          0
# intake_type             0
# intake_condition        0
# animal_type             0
# sex_upon_intake         1
# age_upon_intake         0
# breed                   0
# color                   0
# dtype: int64

# %% [markdown]
# There is no one way to deal with null values. What are some of the strategies we can use to deal with them?
#
# - fill nulls with something that shows the value is missing ('unknown', 0)
# - fill nulls with average or median
# - drop those rows/columns

# %% [markdown]
# How, in Pandas, can we fill null values recognized by Pandas as null? Let's practice by filling nulls for the Name column with some placeholder value, like 'No name'.
#
# Helpful link: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html

# %%
# Code here to fill nulls in the Name column
intakes['name'] = intakes['name'].fillna(value='No Name')

# %% [markdown]
# Now let's check for nulls again...

# %%
# Sanity check
intakes.isna().sum()
# Out:
# animal_id           0
# name                0
# datetime            0
# found_location      0
# intake_type         0
# intake_condition    0
# animal_type         0
# sex_upon_intake     1
# age_upon_intake     0
# breed               0
# color               0
# dtype: int64

# %% [markdown]
# Let's try a different strategy for the one lonely null in the 'Sex upon Intake' column - let's just drop that row, since it's only one observation.
#
# Helpful link: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html

# %%
len(intakes)
# Out:
# 124222

# %%
# Code here to drop the whole row where Sex upon Intake is null
intakes = intakes.dropna(subset=['sex_upon_intake'])

# %%
# Copy/paste code from above to re-check for nulls
intakes.isna().sum()
# Out:
# animal_id           0
# name                0
# datetime            0
# found_location      0
# intake_type         0
# intake_condition    0
# animal_type         0
# sex_upon_intake     0
# age_upon_intake     0
# breed               0
# color               0
# dtype: int64

# %% [markdown]
# How do we find sneaky null or nonsense values that aren't marked by Pandas as null?

# %%
# Run this cell without changes
intakes["age_upon_intake"].value_counts()
# Out:
# 1 year       21809
# 2 years      19069
# 1 month      11910
# 3 years       7456
# 2 months      6735
# 4 years       4458
# 4 weeks       4414
# 5 years       4064
# 3 weeks       3620
# 3 months      3279
# 4 months      3203
# 5 months      3073
# 6 years       2717
# 2 weeks       2498
# 6 months      2396
# 7 years       2335
# 8 years       2284
# 7 months      1860
# 10 years      1828
# 9 months      1824
# 8 months      1500
# 9 years       1331
# 10 months     1028
# 1 week        1022
# 1 weeks        888
# 12 years       880
# 11 months      795
# 0 years        754
# 11 years       746
# 1 day          635
# 3 days         578
# 13 years       575
# 2 days         479
# 14 years       383
# 15 years       336
# 4 days         328
# 5 weeks        315
# 6 days         305
# 5 days         180
# 16 years       140
# 17 years        82
# 18 years        47
# 19 years        27
# 20 years        19
# -1 years         5
# 22 years         5
# 25 years         1
# -2 years         1
# 21 years         1
# 23 years         1
# -3 years         1
# 24 years         1
# Name: age_upon_intake, dtype: int64

# %%
intakes['age_upon_intake'].unique()
# Out:
# array(['2 years', '8 years', '11 months', '4 weeks', '4 years', '6 years',
#        '5 months', '14 years', '1 month', '2 months', '18 years',
#        '4 months', '1 year', '6 months', '3 years', '4 days', '1 day',
#        '5 years', '2 weeks', '15 years', '7 years', '3 weeks', '3 months',
#        '12 years', '1 week', '9 months', '10 years', '10 months',
#        '7 months', '9 years', '8 months', '1 weeks', '5 days', '2 days',
#        '11 years', '0 years', '17 years', '3 days', '13 years', '5 weeks',
#        '19 years', '6 days', '16 years', '20 years', '-1 years',
#        '22 years', '23 years', '-2 years', '21 years', '-3 years',
#        '25 years', '24 years'], dtype=object)

# %% [markdown]
# Analyze the values you're finding in the 'Age upon Intake' column. What doesn't quite fit here?
#
# **Note:** using `.value_counts()` is just one way to look at the values of a column. In this case, it works because we can see which values are the most common, and it's verbose enough to show even the less common values that might be problematic.
#
# So - how do we want to deal with the data in here that doesn't make sense?
#
# -

# %% [markdown]
# What if our goal is creating a column with a common standard for age, one which we could sort to see which animals are the oldest or youngest?
#
# First, let's see what that would look like if we try it as the column is now:

# %%
# Run this cell without changes
intakes['age_upon_intake'].sort_values(ascending=True).unique()
# Out:
# array(['-1 years', '-2 years', '-3 years', '0 years', '1 day', '1 month',
#        '1 week', '1 weeks', '1 year', '10 months', '10 years',
#        '11 months', '11 years', '12 years', '13 years', '14 years',
#        '15 years', '16 years', '17 years', '18 years', '19 years',
#        '2 days', '2 months', '2 weeks', '2 years', '20 years', '21 years',
#        '22 years', '23 years', '24 years', '25 years', '3 days',
#        '3 months', '3 weeks', '3 years', '4 days', '4 months', '4 weeks',
#        '4 years', '5 days', '5 months', '5 weeks', '5 years', '6 days',
#        '6 months', '6 years', '7 months', '7 years', '8 months',
#        '8 years', '9 months', '9 years'], dtype=object)

# %% [markdown]
# Let's unpack what is happening in that line of code - I take the column 'Age upon Intake' by itself (as a series), then sort the values from lowest to highest (`ascending=True`), then grab only unique results so we can see how it ordered the values without looking through all 115,088.
#
# Does that do what we want it to? Let's discuss how this worked - how did it sort?
#
# -

# %% [markdown]
# To make our problem a bit easier, without dealing with the different ways that age is broken out, let's only look at animals where the age is given in years. How can we do that?

# %%
# Code here to grab only the animals where age is given in years

# %%
# Check the shape of this subset dataframe

# %%
# Sanity check

# %% [markdown]
# Can we grab only the number of years from this? Let's make a new column where we can put this data.

# %%
# Code here to make a new column, 'Age in Years'



# Did you get a 'SettingWithCopyWarning'? No worries - let's discuss

# %%
# Code here to transform that column to an integer

# %%
# Code here to check your work

# %%
# Code here to check some statistics on our now-numeric column

# %%
# Code here to check the unique values - in order!

# %%
# Let's check the mean for our now-numeric column

# %%
# Now let's check the median

# %% [markdown]
# Let's discuss this column - what does it mean that the mean and median are different? How will that change if we remove some of the nonsense numbers?
#
# -

# %%
# Code here to deal with those nonsense numbers
nonsense_years = ['-3 years', '-2 years', '-1 years']
intakes['age_upon_intake'] = intakes['age_upon_intake'].replace(nonsense_years, '0 years')

# %%
# Sanity check

# %%
# Code here to re-check your mean/median values

# %% [markdown]
# ### Duplicates - another kind of dirty data (sometimes)
#
# Some duplicates are legitimate, some are not - let's explore and discuss!
#
# Let's go back to our full intakes dataframe

# %%
# Check for duplicates

# %%
# Now check specifically for Animal IDs that are duplicated

# %%
# Handle duplicates - only take the 1st intake for each animal
# Save it as a new version, named clean_intakes
clean_intakes = intakes.drop_duplicates(subset=['animal_id'], keep='last')

# %% [markdown]
# ## Group By
#
# We can use a `groupby` function to find out interesting patterns among groups in our data. Let's use one now to find the average age of each animal type in years.

# %%
# Run just a groupby on the animal_type column - what's the output?

# %%
# Add an aggregation function

# %% [markdown]
# ## Merging Dataframes
#
# We were given two data sources here - both an Intakes and an Outcomes CSV. Let's merge them!
#
# ![Merge diagram from Data Science Made Simple](http://www.datasciencemadesimple.com/wp-content/uploads/2017/09/join-or-merge-in-python-pandas-1.png)
#
# [Image from Data Science Made Simple's post on Joining/Merging Pandas Data Frames](http://www.datasciencemadesimple.com/join-merge-data-frames-pandas-python/)

# %%
# Read in our outcomes csv as a dataframe named outcomes

# %%
# Check out our outcomes data

# %% [markdown]
# What column should we use to merge these DataFrames?
#
# -

# %% [markdown]
# Let's do some quick cleaning on our outcomes dataframe...

# %%
# Change the 'DateTime' column here to be recognized as datetime objects

# %%
# Change column names to be lower case and remove spaces

# %%
# Drop duplicate animal IDs, keeping only the 1st
# Save this as clean_outcomes
clean_outcomes = None

# %%
# Sanity check

# %% [markdown]
# Now... let's merge!

# %%
# Code here to merge dataframes

# %%
# Code here to check out the details of our new dataframe

# %% [markdown]
# Let's discuss - can anyone guess why I had us remove duplicates before this merge? What would happen if I didn't? How could we make our combined_df better?
#
# -

# %% [markdown]
# ## Level Up!
#
# 1. Find the **age in days** for all animals, not just the ones whose age is provided in years. Be sure to do this on the original dataframe, not just on subsets of the dataframe.
#
#    - (Assume a year is 365 days, and a month is 30 days)
#
#
# 2. Ask a few questions of the combined dataframe that you couldn't figure out by just looking at the intakes or outcomes dataframes by themselves.
#
#    - Example: Can you find out how long each animal in the combined dataframe has been in the shelter?
#
#        - Hint: Check out Date Time objects - a new data type that isn't a string or an integer, but which Pandas can recognize as time! https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html

# %%
# Code here to work on level up #1
clean_intakes['age_upon_intake']
# Out:
# 0           2 years
# 1           8 years
# 2         11 months
# 3           4 weeks
# 4           4 years
#             ...
# 124217      2 years
# 124218       1 year
# 124219      4 years
# 124220      3 years
# 124221      2 years
# Name: age_upon_intake, Length: 111012, dtype: object

# %%
clean_intakes.head()
# Out:
#   animal_id     name            datetime                       found_location  \
# 0   A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1   A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2   A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 3   A665644  No Name 2013-10-21 07:59:00                          Austin (TX)
# 4   A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
#
#   intake_type intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0       Stray           Normal         Dog   Neutered Male         2 years
# 1       Stray           Normal         Dog   Spayed Female         8 years
# 2       Stray           Normal         Dog     Intact Male       11 months
# 3       Stray             Sick         Cat   Intact Female         4 weeks
# 4       Stray           Normal         Dog   Neutered Male         4 years
#
#                                    breed        color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
clean_intakes['age_upon_intake'].map(lambda x: x.split(" "))
# Out:
# 0           [2, years]
# 1           [8, years]
# 2         [11, months]
# 3           [4, weeks]
# 4           [4, years]
#               ...
# 124217      [2, years]
# 124218       [1, year]
# 124219      [4, years]
# 124220      [3, years]
# 124221      [2, years]
# Name: age_upon_intake, Length: 111012, dtype: object

# %%
clean_intakes['age_upon_intake'].map(lambda x: x.split(" "))
# Out:
# 0           [2, years]
# 1           [8, years]
# 2         [11, months]
# 3           [4, weeks]
# 4           [4, years]
#               ...
# 124217      [2, years]
# 124218       [1, year]
# 124219      [4, years]
# 124220      [3, years]
# 124221      [2, years]
# Name: age_upon_intake, Length: 111012, dtype: object

# %%
clean_intakes['age_upon_intake'].map(lambda x: int(x[0])*365 if ("year" in x.split(" ")[1])
                                     else (int(x[0])*30 if ('month') in x.split(" ")[1]
                                     else x[0]))

# %%
def find_days(series):
    return series.map(lambda x: int(x[0])*365 if ("year" in x.split(" ")[1])
               else (int(x[0])*30 if ('month') in x.split(" ")[1]
                    else x[0]))
    

clean_intakes['age_days'] = find_days(clean_intakes['age_upon_intake'])
clean_intakes.head(50)
# Out:
# <ipython-input-48-469b4c5432cc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_intakes['age_days'] = find_days(clean_intakes['age_upon_intake'])
#    animal_id         name            datetime  \
# 0    A786884       *Brock 2019-01-03 16:19:00
# 1    A706918        Belle 2015-07-05 12:59:00
# 2    A724273      Runster 2016-04-14 18:43:00
# 3    A665644      No Name 2013-10-21 07:59:00
# 4    A682524          Rio 2014-06-29 10:38:00
# 5    A743852         Odin 2017-02-18 12:46:00
# 6    A635072      Beowulf 2019-04-16 09:53:00
# 7    A708452       Mumble 2015-07-30 14:37:00
# 8    A818975      No Name 2020-06-18 14:53:00
# 9    A774147      No Name 2018-06-11 07:45:00
# 11   A760053      No Name 2017-10-11 15:46:00
# 12   A707375  *Candy Cane 2015-07-11 18:19:00
# 13   A696408       *Pearl 2015-02-04 12:58:00
# 14   A790209        Ziggy 2019-03-06 14:31:00
# 15   A743114      No Name 2017-02-04 10:10:00
# 16   A657188        Tommy 2013-11-10 17:19:00
# 17   A783861        Tulip 2018-11-07 15:53:00
# 18   A707658        *Mint 2015-07-15 17:43:00
# 19   A736287    *Twilight 2016-10-08 11:53:00
# 20   A697950      No Name 2015-03-04 11:22:00
# 21   A298074       Stumpy 2015-09-06 14:21:00
# 23   A810994      No Name 2019-12-25 00:05:00
# 24   A769764      No Name 2018-04-09 19:03:00
# 25   A707974   *Cleopatra 2015-07-20 18:13:00
# 26   A682230      No Name 2014-06-25 16:27:00
# 27   A749436      No Name 2017-05-15 09:50:00
# 28   A722979      No Name 2016-03-24 16:39:00
# 29   A803723      No Name 2019-09-05 12:00:00
# 31   A759935        Dieve 2017-10-09 22:39:00
# 32   A666877       *Romeo 2013-11-08 15:24:00
# 34   A706507      No Name 2015-06-29 17:04:00
# 35   A732903       *Raven 2016-08-14 15:02:00
# 36   A789526       Sixlet 2019-02-23 11:22:00
# 37   A749400      *Pepper 2017-05-14 14:19:00
# 38   A727838      No Name 2016-05-26 14:01:00
# 39   A821389     *Dim Sum 2020-08-10 14:10:00
# 40   A769816     *Wallace 2018-04-10 16:46:00
# 41   A701811      No Name 2015-05-05 07:29:00
# 42   A812244      No Name 2020-01-18 14:14:00
# 44   A724378        Boxer 2016-04-16 13:36:00
# 46   A759995      No Name 2017-10-11 11:48:00
# 47   A702931        Henry 2015-05-19 13:23:00
# 48   A745133       *Magic 2017-03-13 12:50:00
# 51   A736501       Travis 2016-10-11 16:43:00
# 52   A755102      Talesin 2017-07-29 11:49:00
# 53   A699608      No Name 2015-03-30 15:23:00
# 54   A810820      No Name 2019-12-21 11:09:00
# 55   A714578      *Dillon 2015-10-25 12:59:00
# 56   A793043      No Name 2019-04-18 16:06:00
# 57   A721791      No Name 2016-03-04 14:18:00
#
#                                       found_location         intake_type  \
# 0                2501 Magin Meadow Dr in Austin (TX)               Stray
# 1                   9409 Bluegrass Dr in Austin (TX)               Stray
# 2                 2818 Palomino Trail in Austin (TX)               Stray
# 3                                        Austin (TX)               Stray
# 4                      800 Grove Blvd in Austin (TX)               Stray
# 5                                        Austin (TX)     Owner Surrender
# 6                415 East Mary Street in Austin (TX)       Public Assist
# 7                                        Austin (TX)       Public Assist
# 8              Braker Lane And Metric in Travis (TX)               Stray
# 9                      6600 Elm Creek in Austin (TX)               Stray
# 11            8800 South First Street in Austin (TX)               Stray
# 12      Galilee Court And Damita Jo Dr in Manor (TX)               Stray
# 13                       9705 Thaxton in Austin (TX)               Stray
# 14                 4424 S Mopac Expwy in Austin (TX)       Public Assist
# 15                      208 Beaver St in Austin (TX)               Stray
# 16                                       Austin (TX)     Owner Surrender
# 17              3110 Guadalupe Street in Austin (TX)               Stray
# 18                       6118 Fairway in Austin (TX)               Stray
# 19           South First And Stassney in Austin (TX)               Stray
# 20                      1501 S Fm 973 in Austin (TX)               Stray
# 21                     1801 Westridge in Austin (TX)               Stray
# 23                    7900 Rm 1826 Rd in Travis (TX)            Wildlife
# 24           7500 South Interstate 35 in Austin (TX)               Stray
# 25                       2307 Ventura in Austin (TX)               Stray
# 26                      3737 Keats Dr in Austin (TX)               Stray
# 27  East Pleasant Valley And Stassney in Austin (TX)               Stray
# 28                   4100 Westbank Dr in Austin (TX)            Wildlife
# 29               10508 Twilight Vista in Austin (TX)               Stray
# 31                 4800 Cottonwood St in Austin (TX)               Stray
# 32                Guadalupe/St. Johns in Austin (TX)               Stray
# 34                   5306  Peppertree in Austin (TX)               Stray
# 35                                       Austin (TX)               Stray
# 36               2504 Stratford Drive in Austin (TX)               Stray
# 37                      1834 Ferguson in Austin (TX)               Stray
# 38                   2504 Huntwick Dr in Austin (TX)               Stray
# 39          7800 San Felipe Boulevard in Austin (TX)               Stray
# 40           17833 Basket Flower Bend in Travis (TX)               Stray
# 41                  4434 Frontier Trl in Austin (TX)               Stray
# 42                                       Travis (TX)     Owner Surrender
# 44                                       Austin (TX)     Owner Surrender
# 46              1709 East 38Th Street in Austin (TX)               Stray
# 47                                       Austin (TX)  Euthanasia Request
# 48          11699 James B Connolly Ln in Austin (TX)               Stray
# 51                                       Austin (TX)     Owner Surrender
# 52           18120 River Timber Drive in Travis (TX)               Stray
# 53            1054 Springdale Rd #108 in Austin (TX)               Stray
# 54         20209 Grover Cleaveland Way in Manor (TX)               Stray
# 55                      8220 W Hwy 71 in Austin (TX)               Stray
# 56             127 West Anderson Lane in Austin (TX)               Stray
# 57                        12928 Ceder in Travis (TX)               Stray
#
#    intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0            Normal         Dog   Neutered Male         2 years
# 1            Normal         Dog   Spayed Female         8 years
# 2            Normal         Dog     Intact Male       11 months
# 3              Sick         Cat   Intact Female         4 weeks
# 4            Normal         Dog   Neutered Male         4 years
# 5            Normal         Dog   Neutered Male         2 years
# 6            Normal         Dog   Neutered Male         6 years
# 7            Normal         Dog     Intact Male         2 years
# 8            Normal         Cat     Intact Male         4 weeks
# 9           Injured         Cat   Intact Female         4 weeks
# 11           Normal         Dog     Intact Male         2 years
# 12           Normal         Dog   Intact Female        5 months
# 13           Normal         Dog   Intact Female         2 years
# 14           Normal         Cat   Intact Female         4 years
# 15          Injured         Cat   Intact Female         2 years
# 16           Normal         Cat   Neutered Male        14 years
# 17           Normal         Cat   Intact Female         1 month
# 18           Normal         Cat   Intact Female         4 weeks
# 19           Normal         Cat   Intact Female         1 month
# 20           Normal         Dog   Intact Female        2 months
# 21           Normal         Dog   Spayed Female        18 years
# 23           Normal       Other         Unknown         2 years
# 24           Normal         Dog   Intact Female        5 months
# 25           Normal         Cat   Intact Female         2 years
# 26           Normal         Dog   Intact Female        5 months
# 27           Normal         Dog     Intact Male        4 months
# 28           Normal       Other         Unknown          1 year
# 29           Normal         Cat         Unknown        6 months
# 31           Normal         Dog   Intact Female         1 month
# 32           Normal         Dog     Intact Male          1 year
# 34           Normal         Cat         Unknown          4 days
# 35          Injured         Dog   Intact Female        2 months
# 36           Normal         Cat   Intact Female         1 month
# 37           Normal         Cat   Intact Female           1 day
# 38           Normal         Cat   Intact Female         2 years
# 39           Normal         Cat     Intact Male         4 weeks
# 40           Normal         Dog     Intact Male         5 years
# 41          Nursing         Cat         Unknown         2 weeks
# 42           Normal         Dog     Intact Male         1 month
# 44           Normal         Dog     Intact Male         4 years
# 46           Normal         Cat         Unknown        4 months
# 47             Aged       Other         Unknown         2 years
# 48           Normal         Dog     Intact Male          1 year
# 51             Sick         Cat   Neutered Male        15 years
# 52           Normal         Cat   Spayed Female         8 years
# 53           Normal         Cat   Intact Female          1 year
# 54           Normal         Dog   Spayed Female         7 years
# 55           Normal         Cat     Intact Male         2 weeks
# 56           Normal         Cat     Intact Male         2 weeks
# 57           Normal         Dog     Intact Male        2 months
#
#                                        breed                color age_days
# 0                                 Beagle Mix             Tricolor      730
# 1                   English Springer Spaniel          White/Liver     2920
# 2                                Basenji Mix          Sable/White       30
# 3                     Domestic Shorthair Mix               Calico        4
# 4      Doberman Pinsch/Australian Cattle Dog             Tan/Gray     1460
# 5                     Labrador Retriever Mix            Chocolate      730
# 6                             Great Dane Mix                Black     2190
# 7                     Labrador Retriever Mix          Black/White      730
# 8                         Domestic Shorthair          Cream Tabby        4
# 9                     Domestic Shorthair Mix          Black/White        4
# 11                       Chihuahua Shorthair            White/Tan      730
# 12                                  Pit Bull          Brown/White      150
# 13                       Chihuahua Shorthair             Tricolor      730
# 14                    Domestic Shorthair Mix    Brown Tabby/White     1460
# 15                    Domestic Shorthair Mix          Black/White      730
# 16                    Domestic Shorthair Mix    Brown Tabby/White      365
# 17                    Domestic Shorthair Mix          Brown Tabby       30
# 18                    Domestic Shorthair Mix          Black/White        4
# 19                    Domestic Shorthair Mix               Torbie       30
# 20  Australian Cattle Dog/Labrador Retriever            Tan/White       60
# 21                Parson Russell Terrier Mix          Black/White      365
# 23                                       Bat                Brown      730
# 24                     Yorkshire Terrier Mix          White/Black      150
# 25                    Domestic Shorthair Mix                 Blue      730
# 26                               Maltese Mix                White      150
# 27                             Dachshund Mix          Brown/White      120
# 28                                   Bat Mix                Brown      365
# 29                        Domestic Shorthair          Black/White      180
# 31                    Labrador Retriever Mix                Black       30
# 32                             Dachshund Mix            Tan/White      365
# 34                    Domestic Shorthair Mix                Black        4
# 35                    Labrador Retriever Mix          Black/White       60
# 36                    Domestic Shorthair Mix                Black       30
# 37                    Domestic Shorthair Mix                 Blue        1
# 38                    Domestic Shorthair Mix                Black      730
# 39                        Domestic Shorthair          Brown Tabby        4
# 40                           Plott Hound Mix  Brown Brindle/White     1825
# 41                    Domestic Shorthair Mix           Gray Tabby        2
# 42                        Labrador Retriever                  Tan       30
# 44                       Tibetan Spaniel Mix          Black/White     1460
# 46                    Domestic Shorthair Mix          Brown Tabby      120
# 47                               Hamster Mix           White/Gray      730
# 48                   Chihuahua Shorthair Mix                  Tan      365
# 51                    Domestic Shorthair Mix                Black      365
# 52                     Domestic Longhair Mix               Torbie     2920
# 53                    Domestic Shorthair Mix                Black      365
# 54                         Yorkshire Terrier           Black/Gray     2555
# 55                    Domestic Shorthair Mix          Brown Tabby        2
# 56                    Domestic Shorthair Mix          Brown Tabby        2
# 57             Dachshund/Chihuahua Shorthair          Brown Merle       60

# %%
def find_days(series):
    for x in series:
        if 'year' in x[1]:
            days = int(x[0]) * 365
        elif 'month' in x[1]:
            days = int(x[0]) * 30
        else:
            days = int(x[0])
    return days

clean_intakes['age_days'] = find_days(clean_intakes['age_upon_intake'])
clean_intakes.tail(50)
# Out:
# <ipython-input-49-82cc3bf5b260>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_intakes['age_days'] = find_days(clean_intakes['age_upon_intake'])
#        animal_id        name            datetime  \
# 124170   A830109     Chopper 2021-03-07 09:00:00
# 124171   A830329     No Name 2021-03-07 15:29:00
# 124172   A830157       *Newt 2021-03-03 13:48:00
# 124173   A773315        Tofu 2021-03-08 15:10:00
# 124174   A830362     No Name 2021-03-08 15:53:00
# 124176   A830379     No Name 2021-03-08 15:39:00
# 124177   A804495      Peewee 2021-03-08 15:50:00
# 124178   A830381     No Name 2021-03-08 15:41:00
# 124179   A830384     No Name 2021-03-08 15:56:00
# 124180   A828280      Reggie 2021-03-08 16:59:00
# 124181   A830239     No Name 2021-03-05 09:52:00
# 124182   A830240       Simba 2021-03-05 10:30:00
# 124183   A830275     No Name 2021-03-06 09:35:00
# 124184   A731794     No Name 2021-03-07 19:43:00
# 124185   A830268     No Name 2021-03-05 17:25:00
# 124186   A830390     No Name 2021-03-08 17:17:00
# 124187   A830386     No Name 2021-03-08 17:17:00
# 124188   A830371     No Name 2021-03-08 13:36:00
# 124189   A830388     No Name 2021-03-08 17:17:00
# 124190   A830361     No Name 2021-03-08 13:09:00
# 124191   A759467        Yeyo 2021-03-07 11:38:00
# 124192   A830343     No Name 2021-03-08 10:15:00
# 124193   A830389     No Name 2021-03-08 17:17:00
# 124194   A830387     No Name 2021-03-08 17:17:00
# 124195   A830403     No Name 2021-03-08 22:11:00
# 124196   A830360     No Name 2021-03-08 13:36:00
# 124197   A830392     *Scotty 2021-03-08 16:46:00
# 124198   A830241     No Name 2021-03-05 10:29:00
# 124199   A830169   *Sparkles 2021-03-03 15:19:00
# 124200   A830373     *Claire 2021-03-08 12:54:00
# 124201   A830150       Bongo 2021-03-03 11:39:00
# 124202   A830398     No Name 2021-03-08 19:14:00
# 124203   A830137      *Sohjo 2021-03-03 12:26:00
# 124204   A829726    *Nicolas 2021-02-22 08:45:00
# 124206   A684992        Reno 2021-03-07 08:30:00
# 124207   A830413     No Name 2021-03-09 11:10:00
# 124208   A830131   *Tiny Tim 2021-03-03 07:40:00
# 124209   A830171  *Moonstone 2021-03-03 17:13:00
# 124210   A830385       Eevee 2021-03-08 15:46:00
# 124211   A830432     No Name 2021-03-09 12:50:00
# 124212   A830425        Zoey 2021-03-09 10:55:00
# 124213   A830427        Naya 2021-03-09 12:07:00
# 124214   A829340    `*Trixie 2021-02-08 14:44:00
# 124215   A830409         Mia 2021-03-09 07:34:00
# 124216   A830433        Kiwi 2021-03-09 12:04:00
# 124217   A830428     No Name 2021-03-09 12:07:00
# 124218   A830411     No Name 2021-03-09 12:40:00
# 124219   A830250     *Hansel 2021-03-05 14:31:00
# 124220   A830431       Chema 2021-03-09 12:04:00
# 124221   A830251     *Gretel 2021-03-05 14:31:00
#
#                                        found_location      intake_type  \
# 124170                                    Austin (TX)    Public Assist
# 124171                          Fm 812 in Travis (TX)            Stray
# 124172                    13425 Fm 620 in Austin (TX)            Stray
# 124173                    5100 Caswell in Austin (TX)            Stray
# 124174            1400 Brighton Circle in Austin (TX)            Stray
# 124176                49Th And Airport in Austin (TX)            Stray
# 124177              1127 Chicon Street in Austin (TX)            Stray
# 124178                8330 Linden Road in Travis (TX)            Stray
# 124179                                    Austin (TX)  Owner Surrender
# 124180                                    Austin (TX)  Owner Surrender
# 124181               700 Lavaca Street in Austin (TX)         Wildlife
# 124182                 8010 Tapo  Lane in Travis (TX)            Stray
# 124183  3101 West Wells Branch Parkway in Travis (TX)         Wildlife
# 124184      204 Lemon Light Lane in Pflugerville (TX)            Stray
# 124185               105 Laguna Court in Bastrop (TX)            Stray
# 124186          124 West Anderson Lane in Austin (TX)            Stray
# 124187          124 West Anderson Lane in Austin (TX)            Stray
# 124188                 Estrellas Drive in Austin (TX)            Stray
# 124189          124 West Anderson Lane in Austin (TX)            Stray
# 124190                  Cedarspur Road in Austin (TX)            Stray
# 124191        1311 South Meadows Drive in Austin (TX)            Stray
# 124192               1513 Forest Trail in Austin (TX)         Wildlife
# 124193          124 West Anderson Lane in Austin (TX)            Stray
# 124194          124 West Anderson Lane in Austin (TX)            Stray
# 124195        9201 Burklund Farms Road in Travis (TX)         Wildlife
# 124196               6330 Harold Court in Austin (TX)            Stray
# 124197                                    Austin (TX)  Owner Surrender
# 124198              2422 Wilson Street in Austin (TX)            Stray
# 124199            9025 Williamson Road in Travis (TX)            Stray
# 124200                                    Travis (TX)  Owner Surrender
# 124201            1409 Coriander Drive in Austin (TX)            Stray
# 124202             2347 Douglas Street in Austin (TX)    Public Assist
# 124203               3401 Palomar Lane in Austin (TX)            Stray
# 124204                          Fm 973 in Travis (TX)            Stray
# 124206          4614 Oakmont Boulevard in Austin (TX)            Stray
# 124207  517 South Pleasant Valley Road in Austin (TX)         Wildlife
# 124208           Woodward And Congress in Austin (TX)            Stray
# 124209           1310 West Howard Lane in Austin (TX)            Stray
# 124210            3308 Thompson Street in Austin (TX)            Stray
# 124211                                    Austin (TX)            Stray
# 124212                                    Austin (TX)  Owner Surrender
# 124213                                    Austin (TX)  Owner Surrender
# 124214                8801 South Ih 35 in Austin (TX)            Stray
# 124215                                    Austin (TX)  Owner Surrender
# 124216                                    Austin (TX)  Owner Surrender
# 124217              501 Strichen Drive in Travis (TX)         Wildlife
# 124218                 12609 Dessau Rd in Austin (TX)            Stray
# 124219    Cesar Chavez And North Lamar in Austin (TX)            Stray
# 124220                                    Austin (TX)  Owner Surrender
# 124221    Cesar Chavez And North Lamar in Austin (TX)            Stray
#
#        intake_condition animal_type sex_upon_intake age_upon_intake  \
# 124170           Normal         Dog     Intact Male         2 years
# 124171             Sick         Dog   Intact Female        7 months
# 124172          Injured         Cat     Intact Male        4 months
# 124173          Injured         Dog   Neutered Male         3 years
# 124174          Medical         Dog     Intact Male         5 years
# 124176           Normal         Cat   Intact Female         2 years
# 124177           Normal         Dog     Intact Male         3 years
# 124178           Normal         Dog     Intact Male         2 years
# 124179           Normal         Cat   Spayed Female         2 years
# 124180           Normal         Dog   Neutered Male         4 years
# 124181             Sick       Other         Unknown          1 year
# 124182          Injured         Cat   Neutered Male        10 years
# 124183          Injured       Other         Unknown         2 years
# 124184           Normal         Dog   Neutered Male         4 years
# 124185           Normal         Dog     Intact Male         2 years
# 124186           Normal         Dog     Intact Male        3 months
# 124187           Normal         Dog     Intact Male         2 years
# 124188           Normal         Dog   Intact Female         2 years
# 124189           Normal         Dog     Intact Male         2 years
# 124190           Normal         Dog     Intact Male         2 years
# 124191          Injured         Dog   Neutered Male         5 years
# 124192          Injured       Other         Unknown         2 years
# 124193           Normal         Dog     Intact Male         2 years
# 124194           Normal         Dog     Intact Male        3 months
# 124195          Injured       Other         Unknown          1 year
# 124196          Injured         Dog   Intact Female          1 year
# 124197           Normal         Dog   Neutered Male         3 years
# 124198          Injured         Cat   Spayed Female         2 years
# 124199           Normal         Dog   Intact Female         2 years
# 124200           Normal         Cat   Intact Female          1 year
# 124201           Normal         Dog   Neutered Male         2 years
# 124202           Normal         Dog   Intact Female         6 years
# 124203          Nursing         Cat     Intact Male         3 weeks
# 124204          Injured         Dog     Intact Male         2 years
# 124206           Normal         Dog     Intact Male         7 years
# 124207             Sick       Other         Unknown         2 years
# 124208             Sick         Dog     Intact Male        4 months
# 124209           Normal         Dog   Intact Female        7 months
# 124210           Normal         Cat   Spayed Female         2 years
# 124211           Normal         Cat   Intact Female         2 years
# 124212           Normal         Dog   Spayed Female         2 years
# 124213           Normal         Dog   Spayed Female         2 years
# 124214           Normal         Dog   Intact Female          1 year
# 124215          Injured         Dog   Spayed Female        4 months
# 124216           Normal         Dog         Unknown         3 years
# 124217             Sick       Other         Unknown         2 years
# 124218           Normal         Dog     Intact Male          1 year
# 124219           Normal         Dog     Intact Male         4 years
# 124220           Normal         Dog         Unknown         3 years
# 124221           Normal         Dog   Intact Female         2 years
#
#                                           breed                color  age_days
# 124170                                 Pit Bull          Black/White         2
# 124171                      Chihuahua Shorthair                 Blue         2
# 124172                   Domestic Shorthair Mix          Black/White         2
# 124173                             Pit Bull Mix          White/Brown         2
# 124174   American Pit Bull Terrier/Basset Hound           Blue/White         2
# 124176                       Domestic Shorthair    Brown Tabby/White         2
# 124177        Chihuahua Shorthair/Cairn Terrier            Black/Tan         2
# 124178  Treeing Walker Coonhound/Great Pyrenees            Blue Tick         2
# 124179                       Domestic Shorthair               Torbie         2
# 124180                   Labrador Retriever Mix         Yellow/White         2
# 124181                                      Bat                Black         2
# 124182                       Domestic Shorthair         Orange/White         2
# 124183                                  Opossum          Brown/White         2
# 124184                   Labrador Retriever Mix                Black         2
# 124185                   Labrador Retriever Mix                 Gold         2
# 124186                                 Papillon          Brown/White         2
# 124187                                 Papillon          Brown/White         2
# 124188                                 Pit Bull           Gray/White         2
# 124189                                 Papillon          Brown/White         2
# 124190                                 Pit Bull          Black/White         2
# 124191                             Pit Bull Mix                White         2
# 124192                                  Raccoon                Brown         2
# 124193                                 Papillon          Brown/White         2
# 124194                                 Papillon          Brown/White         2
# 124195                                      Bat                Brown         2
# 124196           American Staffordshire Terrier            Red/White         2
# 124197                        Yorkshire Terrier          Brown/Black         2
# 124198                       Domestic Shorthair                Black         2
# 124199                                 Pit Bull          Black/White         2
# 124200                       Domestic Shorthair          Brown Tabby         2
# 124201                          Chinese Sharpei                Brown         2
# 124202              Pit Bull/Labrador Retriever          Black/Brown         2
# 124203                       Domestic Shorthair     White/Blue Tabby         2
# 124204                    Australian Kelpie Mix          Black/Brown         2
# 124206                         Catahoula/Beagle            White/Tan         2
# 124207                                   Coyote             Red/Gray         2
# 124208          Labrador Retriever/Bull Terrier          Black/White         2
# 124209                    Australian Kelpie Mix  Brown Brindle/White         2
# 124210                       Domestic Shorthair                Black         2
# 124211                       Domestic Shorthair          White/Black         2
# 124212                                 Pit Bull           Blue/White         2
# 124213                      German Shepherd Mix          Brown/Black         2
# 124214                  Flat Coat Retriever Mix                Black         2
# 124215                           Pug/Pomeranian                Cream         2
# 124216            Chihuahua Shorthair/Dachshund          Black/Brown         2
# 124217                                    Skunk          Black/White         2
# 124218                    Dachshund/Rat Terrier          Brown/White         2
# 124219                          German Shepherd          Brown/Black         2
# 124220               Beagle/Chihuahua Shorthair          Black/Brown         2
# 124221                          German Shepherd          Brown/Black         2

# %%
pre_norm_age = clean_intakes['age_upon_intake'].map(lambda x: x.split(" "))
pre_norm_age
# Out:
# 0           [2, years]
# 1           [8, years]
# 2         [11, months]
# 3           [4, weeks]
# 4           [4, years]
#               ...
# 124217      [2, years]
# 124218       [1, year]
# 124219      [4, years]
# 124220      [3, years]
# 124221      [2, years]
# Name: age_upon_intake, Length: 111012, dtype: object

# %%
clean_intakes['age_value'] = pre_norm_age.map(lambda x: int(x[0]))
clean_intakes.head()
# Out:
# <ipython-input-51-a4a6870c9002>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_intakes['age_value'] = pre_norm_age.map(lambda x: int(x[0]))
#   animal_id     name            datetime                       found_location  \
# 0   A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1   A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2   A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 3   A665644  No Name 2013-10-21 07:59:00                          Austin (TX)
# 4   A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
#
#   intake_type intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0       Stray           Normal         Dog   Neutered Male         2 years
# 1       Stray           Normal         Dog   Spayed Female         8 years
# 2       Stray           Normal         Dog     Intact Male       11 months
# 3       Stray             Sick         Cat   Intact Female         4 weeks
# 4       Stray           Normal         Dog   Neutered Male         4 years
#
#                                    breed        color  age_days  age_value
# 0                             Beagle Mix     Tricolor         2          2
# 1               English Springer Spaniel  White/Liver         2          8
# 2                            Basenji Mix  Sable/White         2         11
# 3                 Domestic Shorthair Mix       Calico         2          4
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray         2          4

# %%
clean_intakes['age_time'] = pre_norm_age.map(lambda x: x[1])
clean_intakes.head()
# Out:
# <ipython-input-52-b5be3babe801>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_intakes['age_time'] = pre_norm_age.map(lambda x: x[1])
#   animal_id     name            datetime                       found_location  \
# 0   A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1   A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2   A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 3   A665644  No Name 2013-10-21 07:59:00                          Austin (TX)
# 4   A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
#
#   intake_type intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0       Stray           Normal         Dog   Neutered Male         2 years
# 1       Stray           Normal         Dog   Spayed Female         8 years
# 2       Stray           Normal         Dog     Intact Male       11 months
# 3       Stray             Sick         Cat   Intact Female         4 weeks
# 4       Stray           Normal         Dog   Neutered Male         4 years
#
#                                    breed        color  age_days  age_value  \
# 0                             Beagle Mix     Tricolor         2          2
# 1               English Springer Spaniel  White/Liver         2          8
# 2                            Basenji Mix  Sable/White         2         11
# 3                 Domestic Shorthair Mix       Calico         2          4
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray         2          4
#
#   age_time
# 0    years
# 1    years
# 2   months
# 3    weeks
# 4    years

# %%
clean_intakes['age_days'] = clean_intakes['age_value'].map(lambda x: x * 
                                                           (365 if ('year' | 'years') in clean_intakes['age_time']
                                                            else ((30 if ('month' | 'months') in clean_intakes['age_time'])
                                                                  else 1)))
# Out:
#   File "<ipython-input-53-2c14dc0c2331>", line 3
#     else ((30 if ('month' | 'months') in clean_intakes['age_time'])
#                                                                   ^
# SyntaxError: invalid syntax

# %%
for b in a:
    if b[1] == 'years':
        a = int(b[0]) * 365
    elif b[1] == 'months':
        a = int(b[0]) * 30
    else:
        a = int(b[0])

# %%
pre_norm_age.map(lambda x: (int(x[0]) * 365) if x[1] == 'years'
                  else (int(x[0]) * 30 if x[1] == 'months'
                        else (int(x))))

# %%
# Code here to work on level up #2
